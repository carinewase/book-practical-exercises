# %%
print('fit a model with', 11, 'variables')
print
# Out:
# fit a model with 11 variables
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
3+5
# Out:
# 8

# %%
"hello" + " " + "world"
# Out:
# 'hello world'

# %%
y = [4, 9, 7]
x+y
# Out:
# [3, 4, 5, 4, 9, 7]

# %%
x = [3, 4, 5]
x
# Out:
# [3, 4, 5]

# %%
import numpy as np

# %%
x = np.array([3, 4, 5])
y = np.array([4, 9, 7])
x+y
# Out:
# array([ 7, 13, 12])

# %%
x = np.array([[1, 2], [3, 4]])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x.ndim
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('int64')

# %%
np.array([[1, 2], [3.0, 4]]).dtype
np.array
# Out:
# <function numpy.array>

# %%
np.array([[1, 2], [3, 4]], float).dtype
x.shape
# Out:
# (2, 2)

# %%
x = np.array([1, 2, 3, 4])
x.sum()
# Out:
# np.int64(10)

# %%
x = np.array([1, 2, 3, 4])
np.sum(x)
# Out:
# np.int64(10)

# %%
x = np.array([1, 2, 3, 4, 5, 6])
print('beginning x:\n', x)
x_reshape = x.reshape((2, 3))
print('reshaped x:\n', x_reshape)
# Out:
# beginning x:
#  [1 2 3 4 5 6]
# reshaped x:
#  [[1 2 3]
#  [4 5 6]]

# %%
x_reshape[0, 0]
# Out:
# np.int64(1)

# %%
x_reshape[1, 2]
# Out:
# np.int64(6)

# %%
print('x before we modify x_reshape:\n', x)
print('x_reshape before we modify x_reshape:\n', x_reshape)
x_reshape[0, 0] = 5
print('x_reshape after we modify its top left element:\n',
x_reshape)
print('x after we modify top left element of x_reshape:\n', x)
# Out:
# x before we modify x_reshape:
#  [5 2 3 4 5 6]
# x_reshape before we modify x_reshape:
#  [[5 2 3]
#  [4 5 6]]
# x_reshape after we modify its top left element:
#  [[5 2 3]
#  [4 5 6]]
# x after we modify top left element of x_reshape:
#  [5 2 3 4 5 6]

# %%
my_tuple = (3, 4, 5)
my_tuple
# Out:
# (3, 4, 5)

# %%
x_reshape.shape, x_reshape.ndim, x_reshape.T
# Out:
# ((2, 3),
#  2,
#  array([[5, 4],
#         [2, 5],
#         [3, 6]]))

# %%
np.sqrt(x)
# Out:
# array([2.23606798, 1.41421356, 1.73205081, 2.        , 2.23606798,
#        2.44948974])

# %%
x**2
# Out:
# array([25,  4,  9, 16, 25, 36])

# %%
x**0.5
# Out:
# array([2.23606798, 1.41421356, 1.73205081, 2.        , 2.23606798,
#        2.44948974])

# %%
x = np.random.normal(size=50)
x
# Out:
# array([-0.8841184 ,  0.02431559,  0.33172214,  1.73484306, -2.47036585,
#         0.17836721, -1.20275014, -0.59385951,  0.61099421, -1.79607915,
#        -0.09693697,  0.92771291, -1.19829805, -0.10755638, -1.02164396,
#         0.22915779, -1.74966566,  1.23218921, -0.30774815,  1.86668196,
#         0.56211428,  0.61389263, -0.337292  ,  1.3198939 , -0.04967707,
#         0.78940659, -0.52647264,  0.23205947,  0.20944198, -1.00400824,
#         1.25320407, -0.20696697,  0.05802201,  1.37787703,  0.20839128,
#         1.12776424, -1.47088353,  1.65298604,  1.98352501,  0.70896286,
#        -0.56744819,  1.65842161,  0.75283238, -1.33708037,  0.34817795,
#        -0.73670998,  0.73914228,  1.16500254, -0.19685901, -1.41827047])

# %%
y = x + np.random.normal(loc=50, scale=1, size=50)
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.78533066],
#        [0.78533066, 1.        ]])

# %%
print(np.random.normal(scale=5, size=2))
print(np.random.normal(scale=5, size=2))
# Out:
# [1.64908567 0.75388815]
# [-0.7078955  -5.30373185]

# %%
rng = np.random.default_rng(1303)
print(rng.normal(scale=5, size=2))
rng2 = np.random.default_rng(1303)
print(rng2.normal(scale=5, size=2))
# Out:
# [ 4.09482632 -1.07485605]
# [ 4.09482632 -1.07485605]

# %%
rng = np.random.default_rng(3)
y = rng.standard_normal(10)
np.mean(y), y.mean()
# Out:
# (np.float64(-0.1126795190952861), np.float64(-0.1126795190952861))

# %%
np.var(y), y.var(), np.mean((y - y.mean())**2)
# Out:
# (np.float64(2.7243406406465125),
#  np.float64(2.7243406406465125),
#  np.float64(2.7243406406465125))

# %%
np.sqrt(np.var(y)), np.std(y)
# Out:
# (np.float64(1.6505576756498128), np.float64(1.6505576756498128))

# %%
X = rng.standard_normal((10, 3))
X
# Out:
# array([[ 0.22578661, -0.35263079, -0.28128742],
#        [-0.66804635, -1.05515055, -0.39080098],
#        [ 0.48194539, -0.23855361,  0.9577587 ],
#        [-0.19980213,  0.02425957,  1.54582085],
#        [ 0.54510552, -0.50522874, -0.18283897],
#        [ 0.54052513,  1.93508803, -0.26962033],
#        [-0.24355868,  1.0023136 , -0.88645994],
#        [-0.29172023,  0.88253897,  0.58035002],
#        [ 0.0915167 ,  0.67010435, -2.82816231],
#        [ 1.02130682, -0.95964476, -1.66861984]])

# %%
X.mean(axis=0)
# Out:
# array([ 0.15030588,  0.14030961, -0.34238602])

# %%
X.mean(0)
# Out:
# array([ 0.15030588,  0.14030961, -0.34238602])

# %%
from matplotlib.pyplot import subplots
fig, ax = subplots(figsize=(8, 8))
x = rng.standard_normal(100)
y = rng.standard_normal(100)
ax.plot(x, y);
